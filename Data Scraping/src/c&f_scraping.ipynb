# %% [markdown]
# Begin The Data Scraping

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url ='https://cnfstore.com/sale?cat=77&p={}&product_list_limit=30'
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'
}
listBrand = []
listProdName =[]
listVolume = []
listType = []
listOldPrice = []
listNewPrice = []
listDiscount = []

count_page = 0
count_item=0
for page in range (1,14):
    count_page+=1
    print('scraping page :',count_page)
    req = requests.get(url.format(page), headers=headers)
    soup = BeautifulSoup(req.text, 'html.parser')
    items = soup.findAll('div', 'product-card-wrapper')

    for it in items:
        count_item+=1
        # extract the brand name
        try: brand = it.find('span', 'product-card-brand').text
        except: brand = '-'
        listBrand.append(brand)

        # extract the product name
        prod_name = it.find('a', 'product-card-name').text
        listProdName.append(prod_name)

        # extract the parfume total volume
        match = re.findall(r'(\d+)\s?ml', prod_name)
        total_volume = 0
        for vol in match:
            quantity = int(re.search(r'\d+', vol).group())
            total_volume += quantity
        listVolume.append(total_volume)

        # extract the parfume type
        try: 
            match = re.search(r'ED[PT]', prod_name, flags=re.IGNORECASE)
            type = match.group()
        except: type  = '-'
        listType.append(type)
        
        # extract the old price
        try: 
            old_price = it.find('div','product-card-price').find('div','old-price').find('span','price').text
            old_price = int (old_price.replace('Rp','').replace(' ','').replace('.',''))
        except: old_price = int(0)
        listOldPrice.append(old_price)

        # extract the new price
        try: 
            new_price = it.find('div','product-card-price').find('div','special-price').find('span','price').text
            new_price = int (new_price.replace('Rp','').replace(' ','').replace('.',''))
        except: new_price = int(0)
        listNewPrice.append(new_price)

        # extract the discount
        try: 
            discount = it.find('div','product-card-price').find('div','old-price').find('span','sale-percent').text
            discount = int (discount.replace('-','').replace('%',''))
        except: discount = int(0)
        listDiscount.append(discount)

print(count_item)
# Out:
# scraping page : 1
# scraping page : 2
# scraping page : 3
# scraping page : 4
# scraping page : 5
# scraping page : 6
# scraping page : 7
# scraping page : 8
# scraping page : 9
# scraping page : 10
# scraping page : 11
# scraping page : 12
# scraping page : 13
# 370

# %% [markdown]
# Create a Data Frame

# %%
sale_product_dict = {
    'Brand': listBrand,
    'Product Name': listProdName,
    'Size (ml)': listVolume,
    'Type': listType,
    'Old Price (IDR)': listOldPrice,
    'Special Price (IDR)': listNewPrice,
    'Discount Percentage': listDiscount
}

# create a dataframe
df= pd.DataFrame(sale_product_dict, columns=['Brand','Product Name', 'Size (ml)', 'Type', 'Old Price (IDR)', 'Special Price (IDR)', 'Discount Percentage'])
df.head()
# Out:
#              Brand                                       Product Name  \
# 0      LOUIS VAREL                    Louis Varel My Dream EDP 100 ml
# 1  DOLCE & GABBANA  Dolce & Gabbana Light Blue Intense Man EDP 100 ml
# 2          KORLOFF                             Miss Korloff EDP 88 ml
# 3        HUGO BOSS               Hugo Boss Scent Le Parfum Men 100 ml
# 4            OULLU                              Oullu Umbra EDP 15 ml
#
#    Size (ml) Type  Old Price (IDR)  Special Price (IDR)  Discount Percentage
# 0        100  EDP           620000               434000                   30
# 1        100  EDP                0                    0                    0
# 2         88  EDP          1690000              1521000                   10
# 3        100    -          1680000              1293600                   23
# 4         15  EDP           189000               160650                   15

# %%
# save raw dataframe
df.to_json("C&F_sale_fragrances_raw.json",indent=4)

# %% [markdown]
# Begin Data Cleaning

# %%
# check for duplicate data
print('Total duplicate data:',df.duplicated().sum())
# Out:
# Total duplicate data: 111

# %%
df[df['Product Name'].duplicated()].sort_values('Product Name', ascending=True).head(20)
# Out:
#                Brand                                       Product Name  \
# 296  ANGEL SCHLESSER  Angel Schlesser Instant Vibrant Sandalwood EDT...
# 331      ARMAND BASI    Armand Basi L'Eau Pour Homme Vetiver EDT 125 ml
# 241                -   Avicenna 100 ml + Yves Rocher Body Lotion 390 ML
# 184                -  Avicenna EDP 50 ml + Anessa Day Serum Set Free...
# 250                -  Avicenna EDP 50 ml + Anessa New Perfect UV Sun...
# 298         AVICENNA                 Avicenna Euphoric (New) EDP 100 ml
# 288         AVICENNA                  Avicenna Freedom (New) EDT 100 ml
# 197         AVICENNA                  Avicenna Freedom (New) EDT 100 ml
# 340         AVICENNA                         Avicenna Miracle EDP 50 ml
# 334         AVICENNA                Avicenna VIP Women (New) EDP 100 ml
# 253         AVICENNA                     Avicenna Wild (New) EDT 100 ml
# 261  BEVERLYS SECRET  Beverly's Secret Cherry Blossom Fragrance Mist...
# 205  BEVERLYS SECRET  Beverly's Secret Exotic Dream Fragrance Mist 2...
# 285  BEVERLYS SECRET  Beverly's Secret Exotic Dream Fragrance Mist 2...
# 274  BEVERLYS SECRET  Beverly's Secret Sweet Seduction Fragrance Mis...
# 195  BEVERLYS SECRET  Beverly's Secret Sweet Seduction Fragrance Mis...
# 251  BEVERLYS SECRET  Beverly's Secret Vanilla Sparkle Fragrance Mis...
# 257           BLAUER                        Blauer Journey Man EDP 80ml
# 244     CALVIN KLEIN                       Calvin Klein Defy EDT 100 ml
# 191     CALVIN KLEIN                   Calvin Klein Defy Men EDP 100 ml
#
#      Size (ml) Type  Old Price (IDR)  Special Price (IDR)  Discount Percentage
# 296        100  EDT           990000               792000                   20
# 331        125  EDT          1290000               903000                   30
# 241        100    -                0                    0                    0
# 184         50  EDP                0                    0                    0
# 250         50  EDP                0                    0                    0
# 298        100  EDP           379000               284250                   25
# 288        100  EDT           379000               284250                   25
# 197        100  EDT           379000               284250                   25
# 340         50  EDP           259000               194250                   25
# 334        100  EDP           399000               299250                   25
# 253        100  EDT           379000               284250                   25
# 261        250    -           150000                90000                   40
# 205        250    -           150000                90000                   40
# 285        250    -           150000                90000                   40
# 274        250    -           150000                90000                   40
# 195        250    -           150000                90000                   40
# 251        250    -           150000                90000                   40
# 257         80  EDP           980000               784000                   20
# 244        100  EDT                0                    0                    0
# 191        100  EDP          1800000                    0                   30

# %%
# drop duplicate data
df.drop_duplicates(inplace=True)
print('Total duplicate data:',df.duplicated().sum())
# Out:
# Total duplicate data: 0

# %%
# check for available products
# out of stock products are indicated with 0 value for both old price and special price
df1 = df[(df['Old Price (IDR)'] != 0) & (df['Special Price (IDR)'] != 0)]
print('Available products:', df1.shape[0])
# Out:
# Available products: 230

# %%
# cleaning data from "out of stock" products
df = df[(df['Old Price (IDR)'] != 0) & (df['Special Price (IDR)'] != 0)]
print('Total data rows:',df.shape[0])
df.head(10)
# Out:
# Total data rows: 230
#                 Brand                              Product Name  Size (ml)  \
# 0         LOUIS VAREL           Louis Varel My Dream EDP 100 ml        100
# 2             KORLOFF                    Miss Korloff EDP 88 ml         88
# 3           HUGO BOSS      Hugo Boss Scent Le Parfum Men 100 ml        100
# 4               OULLU                     Oullu Umbra EDP 15 ml         15
# 5   CRISTIANO RONALDO  Cristiano Ronaldo CR7 Origins EDT 100 ml        100
# 6           MONTBLANC               Montblanc Emblem EDT 100 ml        100
# 7         ST. HILAIRE       St. Hilaire Private Blue EDP 100 ml        100
# 9    PERFUME REPUBLIC   Perfume Republic Break A Leg EDT 100 ml        100
# 10      MARCO SERUSSI             Marco Serussi The Man Intense          0
# 11             MUGLER            Mugler Alien Goddess EDP 60 ml         60
#
#    Type  Old Price (IDR)  Special Price (IDR)  Discount Percentage
# 0   EDP           620000               434000                   30
# 2   EDP          1690000              1521000                   10
# 3     -          1680000              1293600                   23
# 4   EDP           189000               160650                   15
# 5   EDT          1180000               826000                   30
# 6   EDT          1400000              1120000                   20
# 7   EDP           530000               371000                   30
# 9   EDT           249000               161850                   35
# 10    -          1030000               824000                   20
# 11  EDP          1680000              1327200                   21

# %%
# display the products that have a type which is neither EDP nor EDT
df[(df['Type'] != 'EDP') & (df['Type'] != 'EDT')]
# Out:
#                Brand                                       Product Name  \
# 3          HUGO BOSS               Hugo Boss Scent Le Parfum Men 100 ml
# 10     MARCO SERUSSI                      Marco Serussi The Man Intense
# 19   BEVERLYS SECRET  Beverly's Secret Sweet Seduction Fragrance Mis...
# 29   BEVERLYS SECRET  Beverly's Secret Exotic Dream Fragrance Mist 2...
# 72   BEVERLYS SECRET  Beverly's Secret Vanilla Sparkle Fragrance Mis...
# 81   BEVERLYS SECRET  Beverly's Secret Cherry Blossom Fragrance Mist...
# 83     MARCO SERUSSI                             Marco Serussi The Lady
# 116      YVES ROCHER      Yves Rocher Body & Hair Mist - Vanilla 100 ml
# 122      YVES ROCHER        Yves Rocher Body & Hair Mist - Olive 100 ml
# 175      YVES ROCHER        Yves Rocher Body & Hair Mist - Mango 100 ml
# 222       LA MARTINA                 La Martina Blue Gardenia EDC 80 ml
# 319  BEVERLYS SECRET  Beverly's Secret Sparkling Beauty Fragrance Mi...
# 328  BEVERLYS SECRET  Beverly's Secret Exotic Bloom Fragrance Mist 2...
#
#      Size (ml) Type  Old Price (IDR)  Special Price (IDR)  Discount Percentage
# 3          100    -          1680000              1293600                   23
# 10           0    -          1030000               824000                   20
# 19         250    -           150000                90000                   40
# 29         250    -           150000                90000                   40
# 72         250    -           150000                90000                   40
# 81         250    -           150000                90000                   40
# 83           0    -          1030000               824000                   20
# 116        100    -           219000               164250                   25
# 122        100    -           219000               164250                   25
# 175        100    -           219000               164250                   25
# 222         80    -          1450000               870000                   40
# 319        250    -           150000                90000                   40
# 328        250    -           150000                90000                   40

# %%
# change all '-' type value with EDC|Body & Hair Mist|Toner|Fragrance Mist corresponding with the product name
df.loc[df['Type'] == '-', 'Type'] = df.loc[df['Type'] == '-', 'Product Name'].str.extract('(EDC|Body & Hair Mist|Toner|Fragrance Mist)', expand=False).fillna('-')
df[(df['Type'] != 'EDP') & (df['Type'] != 'EDT')]
# Out:
#                Brand                                       Product Name  \
# 3          HUGO BOSS               Hugo Boss Scent Le Parfum Men 100 ml
# 10     MARCO SERUSSI                      Marco Serussi The Man Intense
# 19   BEVERLYS SECRET  Beverly's Secret Sweet Seduction Fragrance Mis...
# 29   BEVERLYS SECRET  Beverly's Secret Exotic Dream Fragrance Mist 2...
# 72   BEVERLYS SECRET  Beverly's Secret Vanilla Sparkle Fragrance Mis...
# 81   BEVERLYS SECRET  Beverly's Secret Cherry Blossom Fragrance Mist...
# 83     MARCO SERUSSI                             Marco Serussi The Lady
# 116      YVES ROCHER      Yves Rocher Body & Hair Mist - Vanilla 100 ml
# 122      YVES ROCHER        Yves Rocher Body & Hair Mist - Olive 100 ml
# 175      YVES ROCHER        Yves Rocher Body & Hair Mist - Mango 100 ml
# 222       LA MARTINA                 La Martina Blue Gardenia EDC 80 ml
# 319  BEVERLYS SECRET  Beverly's Secret Sparkling Beauty Fragrance Mi...
# 328  BEVERLYS SECRET  Beverly's Secret Exotic Bloom Fragrance Mist 2...
#
#      Size (ml)              Type  Old Price (IDR)  Special Price (IDR)  \
# 3          100                 -          1680000              1293600
# 10           0                 -          1030000               824000
# 19         250    Fragrance Mist           150000                90000
# 29         250    Fragrance Mist           150000                90000
# 72         250    Fragrance Mist           150000                90000
# 81         250    Fragrance Mist           150000                90000
# 83           0                 -          1030000               824000
# 116        100  Body & Hair Mist           219000               164250
# 122        100  Body & Hair Mist           219000               164250
# 175        100  Body & Hair Mist           219000               164250
# 222         80               EDC          1450000               870000
# 319        250    Fragrance Mist           150000                90000
# 328        250    Fragrance Mist           150000                90000
#
#      Discount Percentage
# 3                     23
# 10                    20
# 19                    40
# 29                    40
# 72                    40
# 81                    40
# 83                    20
# 116                   25
# 122                   25
# 175                   25
# 222                   40
# 319                   40
# 328                   40

# %%
# check for any '-' value left in the Type column
df[(df['Type'] == '-')]
# Out:
#             Brand                          Product Name  Size (ml) Type  \
# 3       HUGO BOSS  Hugo Boss Scent Le Parfum Men 100 ml        100    -
# 10  MARCO SERUSSI         Marco Serussi The Man Intense          0    -
# 83  MARCO SERUSSI                Marco Serussi The Lady          0    -
#
#     Old Price (IDR)  Special Price (IDR)  Discount Percentage
# 3           1680000              1293600                   23
# 10          1030000               824000                   20
# 83          1030000               824000                   20

# %%
# I do a further investigation in C&F website to determine the kind of unknown fragrances' type
df.loc[df['Product Name'] == 'Marco Serussi The Man Intense', 'Type'] = 'EDT'
df.loc[df['Product Name'] == 'Marco Serussi The Lady', 'Type'] = 'EDP'
df.loc[df['Product Name'] == 'Hugo Boss Scent Le Parfum Men 100 ml', 'Type'] = 'EDP'

# %%
# double check '-' values for ''Type' column
df[df['Type'] == '-']
# Out:
# Empty DataFrame
# Columns: [Brand, Product Name, Size (ml), Type, Old Price (IDR), Special Price (IDR), Discount Percentage]
# Index: []

# %%
# check for '0' value in 'Brand' column
df[df['Brand']=='-']
# Out:
# Empty DataFrame
# Columns: [Brand, Product Name, Size (ml), Type, Old Price (IDR), Special Price (IDR), Discount Percentage]
# Index: []

# %%
# check for '0' value in 'Size (ml)' column
df[df['Size (ml)']==0]
# Out:
#             Brand                   Product Name  Size (ml) Type  \
# 10  MARCO SERUSSI  Marco Serussi The Man Intense          0  EDT
# 83  MARCO SERUSSI         Marco Serussi The Lady          0  EDP
#
#     Old Price (IDR)  Special Price (IDR)  Discount Percentage
# 10          1030000               824000                   20
# 83          1030000               824000                   20

# %%
# I do a further investigation in Google to determine the volume of unknown fragrances' size
df.loc[df['Product Name'] == 'Marco Serussi The Man Intense', 'Size (ml)'] = 100
df.loc[df['Product Name'] == 'Marco Serussi The Lady', 'Size (ml)'] = 90

# %%
# double-check for MARCO SERUSSI's fragrances details
df[df['Brand']=='MARCO SERUSSI']
# Out:
#              Brand                              Product Name  Size (ml) Type  \
# 10   MARCO SERUSSI             Marco Serussi The Man Intense        100  EDT
# 83   MARCO SERUSSI                    Marco Serussi The Lady         90  EDP
# 224  MARCO SERUSSI  Marco Serussi Harmony Intense EDP 100 ml        100  EDP
# 310  MARCO SERUSSI  Marco Serussi The Lady Intense EDP 90 ml         90  EDP
# 357  MARCO SERUSSI    Marco Serussi The Man Trust EDT 100 ml        100  EDT
#
#      Old Price (IDR)  Special Price (IDR)  Discount Percentage
# 10           1030000               824000                   20
# 83           1030000               824000                   20
# 224           990000               792000                   20
# 310          1030000               824000                   20
# 357          1030000               824000                   20

# %%
# save cleaned data frame
df.to_json("C&F_sale_fragrances_cleaned.json",indent=4)

# %% [markdown]
# At this moment, I forgot add a column to identify each row. Therefore, I decide to create a new column "id_product", consisting of sequential integers that start with 1. In addition, I'd like to rename all the columns name into snake_case format.

# %%
import pandas as pd
df = pd.read_json("../data/C&F_sale_fragrances_cleaned.json")

# create  new column as an identifier
df['id_product'] = range(1,len(df)+1)

# rename columns name
df = df.rename(columns={'Brand':'brand',
                        'Product Name':'product_name',
                        'Size (ml)':'size_ml',
                        'Type':'type',
                        'Old Price (IDR)':'old_price_idr',
                        'Special Price (IDR)':'special_price_idr',
                        'Discount Percentage':'discount_percentage'})

# reorder the columns
df = df[['id_product',
         'brand',
         'product_name',
         'size_ml',
         'type',
         'old_price_idr',
         'special_price_idr',
         'discount_percentage']]

df.head()
# Out:
#    id_product              brand                              product_name  \
# 0           1        LOUIS VAREL           Louis Varel My Dream EDP 100 ml
# 1           2            KORLOFF                    Miss Korloff EDP 88 ml
# 2           3          HUGO BOSS      Hugo Boss Scent Le Parfum Men 100 ml
# 3           4              OULLU                     Oullu Umbra EDP 15 ml
# 4           5  CRISTIANO RONALDO  Cristiano Ronaldo CR7 Origins EDT 100 ml
#
#    size_ml type  old_price_idr  special_price_idr  discount_percentage
# 0      100  EDP         620000             434000                   30
# 1       88  EDP        1690000            1521000                   10
# 2      100  EDP        1680000            1293600                   23
# 3       15  EDP         189000             160650                   15
# 4      100  EDT        1180000             826000                   30

# %%
df.tail()
# Out:
#      id_product          brand                              product_name  \
# 225         226     MAUBOUSSIN        Mauboussin Private Club EDP 100 ml
# 226         227  SALVADOR DALI  Salvador Dali Eau De Rubylips EDT 100 ml
# 227         228    ARMAND BASI         Armand Basi Night Blue EDT 100 ml
# 228         229      HUGO BOSS             Hugo Boss Selection EDT 90 ml
# 229         230      HUGO BOSS                  Hugo Boss Nuit EDP 75 ml
#
#      size_ml type  old_price_idr  special_price_idr  discount_percentage
# 225      100  EDP        1320000            1122000                   15
# 226      100  EDT        1130000             904000                   20
# 227      100  EDT        1290000            1032000                   20
# 228       90  EDT        1150000             885500                   23
# 229       75  EDP        1480000            1139600                   23

# %%
df.to_json("../data/C&F_sale_fragrances_cleaned.json", orient="records", indent=4)
